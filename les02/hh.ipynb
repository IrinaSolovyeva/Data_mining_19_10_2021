# %%
import pandas as pd

# %%
df = pd.read_csv('hh.csv', sep=';')

# %%
df
# Out:
#                                            name  \
# 0             Python Developer (World of Tanks)
# 1           Python Developer (New game product)
# 2             Python Developer (World of Tanks)
# 3    Python Developer (Infrastructure Projects)
# 4                            Python разработчик
# ..                                          ...
# 775                               Data Engineer
# 776                        QA Engineer (Python)
# 777                          Разработчик Python
# 778            Data Scientist (Computer Vision)
# 779                   Middle Python разработчик
#
#                                                   link  salary_min  \
# 0    https://spb.hh.ru/vacancy/47146423?from=vacanc...         NaN
# 1    https://spb.hh.ru/vacancy/49866239?from=vacanc...         NaN
# 2    https://spb.hh.ru/vacancy/47146424?from=vacanc...         NaN
# 3    https://spb.hh.ru/vacancy/50491842?from=vacanc...         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             780 non-null    object
#  1   link             780 non-null    object
#  2   salary_min       620 non-null    float64
#  3   salary_max       355 non-null    float64
#  4   salary_currency  646 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 30.6+ KB
